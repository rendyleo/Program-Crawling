# %% [markdown]
# <a href="https://colab.research.google.com/github/rendyleo/Program-Crawling/blob/main/Program_crawling_data_website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Rendy Yana Ferdiansyah
#
# Kali ini saya akan melakukan crawling data berita melalui website kompas dengan total 50 berita politik dan 50 berita sport
#
# 1. **Crawling**
#
# adalah proses otomatis untuk mengumpulkan atau menelusuri halaman-halaman web di internet menggunakan program khusus yang disebut web crawler atau spider. Web crawler secara sistematis mengikuti tautan dari satu halaman ke halaman lain, mengunduh dan menyimpan konten halaman tersebut untuk keperluan analisis, pengindeksan, atau pengumpulan data.
#
# Proses crawling biasanya dilakukan oleh mesin pencari seperti Google, Bing, atau Yahoo! untuk mengindeks halaman web sehingga pengguna bisa menemukan informasi melalui hasil pencarian. Namun, crawling juga dapat digunakan dalam banyak aplikasi lain, seperti riset pasar, analisis web, atau pengumpulan data yang terstruktur dari web.
#
#  Cara Kerja Crawling:
# 1. Starting Point: Crawler memulai dari satu atau beberapa URL yang disebut "seed" (awal penjelajahan).
# 2. Menjelajahi Link: Crawler menelusuri halaman yang ditemukan dan mengumpulkan semua tautan yang ada di halaman tersebut.
# 3. Mengunduh Halaman: Halaman web diunduh dan disimpan oleh crawler.
# 4. Pengulangan: Crawler kemudian mengikuti tautan yang ditemukan pada halaman-halaman yang telah dikunjungi, dan proses ini terus berlanjut secara rekursif.
#
#  Kegunaan Crawling:
# - Pengindeksan Mesin Pencari: Mesin pencari menggunakan crawler untuk mengindeks konten halaman web dan membuatnya tersedia dalam hasil pencarian.
# - Web Scraping: Crawling digunakan untuk mengekstrak data tertentu dari halaman web, misalnya untuk riset pasar atau pengumpulan data produk di situs e-commerce.
# - Monitoring Situs Web: Crawlers bisa digunakan untuk memantau perubahan konten pada situs web, misalnya untuk melihat perubahan harga produk atau ketersediaan informasi baru.
#
#  Contoh Crawler:
# - Googlebot: Crawler yang digunakan oleh Google untuk mengindeks halaman-halaman web dan meng-update database mesin pencari mereka.
# - Scrapy: Sebuah framework open-source yang sering digunakan untuk melakukan crawling dan scraping data dari situs web.
#
# Tantangan dalam Crawling:
# - Robots.txt: Banyak situs web yang menggunakan file `robots.txt` untuk memberikan instruksi kepada crawler tentang halaman mana yang boleh atau tidak boleh diakses.
# - Kinerja & Bandwidth: Proses crawling dapat membebani server web jika dilakukan secara berlebihan atau tidak terkendali.
# - Situs Dinamis: Banyak situs modern menggunakan JavaScript untuk memuat konten secara dinamis, yang dapat mempersulit crawling tradisional yang hanya mengunduh HTML statis.
#
# Crawling adalah bagian fundamental dari cara internet bekerja, terutama dalam hal pencarian informasi secara otomatis dan sistematis.

# %% [markdown]
# 2. **Perintah pip install requests beautifulsoup4**
#
# digunakan untuk menginstal dua pustaka Python populer, yaitu Requests dan BeautifulSoup4. Kedua pustaka ini sering digunakan untuk web scraping, yaitu proses mengunduh dan mengekstrak data dari halaman web secara otomatis.

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %% [markdown]
# 3. **requests**
#
# Pustaka requests digunakan untuk mengirimkan permintaan HTTP ke server dan menerima respons berupa halaman web (biasanya dalam format HTML). Ini adalah langkah pertama dalam web scraping untuk mengakses konten dari situs web.

# %% [markdown]
# **Crawling** **Data** **Pemilu**

# %%
import requests

# URL halaman yang ingin diambil
url = 'https://pemilu.kompas.com/?source=navbar'

# Mengambil halaman
response = requests.get(url)

# Periksa status pengambilan
if response.status_code == 200:
    print("Sukses mengambil halaman!")
    html_content = response.text
else:
    print("Gagal mengambil halaman:", response.status_code)
# Out:
# Sukses mengambil halaman!

# %% [markdown]
# **Crawling** **Data** **Sport**

# %%
import requests

# URL halaman yang ingin diambil
url = 'https://bola.kompas.com/'

# Mengambil halaman
response = requests.get(url)

# Periksa status pengambilan
if response.status_code == 200:
    print("Sukses mengambil halaman!")
    html_content = response.text
else:
    print("Gagal mengambil halaman:", response.status_code)
# Out:
# Sukses mengambil halaman!

# %% [markdown]
# 4. Fungsi Program dibawah adalah untuk mengambil isi dari halaman detail berita

# %%
# Fungsi untuk mengambil isi dari halaman detail berita
def get_news_content(news_url):
    response = requests.get(news_url, headers=headers)
    if response.status_code != 200:
        print(f"Gagal mengakses halaman berita: {news_url}")
        return ""

    soup = BeautifulSoup(response.text, 'lxml')

# %% [markdown]
# 5. **BeautifulSoup**
#
# Pustaka BeautifulSoup dari library bs4 digunakan untuk mem-parsing (mengurai) dan mengekstrak informasi dari HTML atau XML. Ini memudahkan penanganan elemen-elemen web seperti tag div, a, table, dll.

# %%
from bs4 import BeautifulSoup

# Parsing HTML menggunakan BeautifulSoup
soup = BeautifulSoup(html_content, 'lxml')

# mengambil judul halaman
page_title = soup.title.text
print("Judul halaman:", page_title)

def get_news_content(news_url):
    response = requests.get(news_url, headers=headers)
    if response.status_code != 200:
        print(f"Gagal mengakses halaman berita: {news_url}")
        return ""

    soup = BeautifulSoup(response.text, 'lxml')
# Out:
# Judul halaman: Berita Bola Terkini, Jadwal Klasemen Liga - Kompas.com

# %% [markdown]
# 6. Program Dibawah Digunakan untuk menemukan elemen (a) (link) dan mencetak semua URL dari Link

# %%
# Menemukan semua elemen <a> (link) di halaman
links = soup.find_all('a')

# Cetak semua URL link
for link in links:
    print(link.get('href'))
# Out:
# https://www.kompas.com
# https://play.kompas.com/loyalty
# javascript:void(0)
# https://account.kompas.com/login/a29tcGFz/aHR0cHM6Ly9ib2xhLmtvbXBhcy5jb20v
# https://activity.kompas.com/voucher?source=navbar
# https://plus.kompas.com
# https://activity.kompas.com/saved
# https://activity.kompas.com/liked
# https://activity.kompas.com/minat
# https://www.kompas.com/feedback
# https://komp.as/darikompascom
# https://www.kompas.com
# https://news.kompas.com?source=navbar
# https://nasional.kompas.com
# https://megapolitan.kompas.com
# https://www.kompas.com/global
# https://inside.kompas.com/suratpembaca
# https://kilasdaerah.kompas.com
# https://kilaskorporasi.kompas.com
# https://kilaskementerian.kompas.com
# https://sorotpolitik.kompas.com
# https://kilasbadannegara.kompas.com
# https://kelanaindonesia.kompas.com
# https://www.kompas.com/topik-pilihan/list/7782/kalbe-health-corner
# https://kilasparlemen.kompas.com
# https://kilasbumn.kompas.com
# https://www.kompas.com/cekfakta
# https://www.kompas.com/konsultasihukum
# https://news.kompas.com/search
# https://regional.kompas.com
# https://surabaya.kompas.com
# https://medan.kompas.com
# https://makassar.kompas.com
# https://yogyakarta.kompas.com
# https://bandung.kompas.com
# https://denpasar.kompas.com
# https://www.kompas.com/hype
# https://pemilu.kompas.com?source=navbar
# https://ikn.kompas.com?source=navbar
# https://ikn.kompas.com/news
# https://ikn.kompas.com/city
# https://ikn.kompas.com/infrastructure
# https://ikn.kompas.com/community
# https://ikn.kompas.com/housings
# https://indeks.kompas.com?site=ikn
# https://ikn.kompas.com/foresta
# https://tekno.kompas.com?source=navbar
# https://tekno.kompas.com/apps-os
# https://tekno.kompas.com/gadget
# https://tekno.kompas.com/internet
# https://tekno.kompas.com/hardware
# https://tekno.kompas.com/business
# https://tekno.kompas.com/game
# https://tekno.kompas.com/galeri
# https://tekno.kompas.com/search
# https://pubads.g.doubleclick.net/gampad/clk?id=6163907479&iu=/31800665/KOMPAS.COM/tekno
# https://kilasinternet.kompas.com/
# https://otomotif.kompas.com?source=navbar
# https://otomotif.kompas.com/motor
# https://otomotif.kompas.com/mobil
# https://otomotif.kompas.com/sport
# https://otomotif.kompas.com/niaga
# https://otomotif.kompas.com/komunitas
# https://otomotif.kompas.com/otopedia
# https://otomotif.kompas.com/merapah
# https://otomotif.kompas.com/ev-leadership
# https://otomotif.kompas.com/elektrifikasi
# https://lipsus.kompas.com/pameranotomotifnasional2024
# https://bola.kompas.com?source=navbar
# https://bola.kompas.com/timnas-indonesia
# https://bola.kompas.com/liga-indonesia
# https://bola.kompas.com/liga-italia
# https://bola.kompas.com/liga-champions
# https://bola.kompas.com/liga-lain
# https://bola.kompas.com/liga-inggris
# https://bola.kompas.com/liga-spanyol
# https://bola.kompas.com/internasional
# https://bola.kompas.com/bundesliga
# https://www.kompas.com/motogp
# https://www.kompas.com/badminton
# https://www.kompas.com/sports
# https://indeks.kompas.com?site=bola
# https://lifestyle.kompas.com?source=navbar
# https://lifestyle.kompas.com/wellness
# https://lifestyle.kompas.com/fashion
# https://lifestyle.kompas.com/relationship
# https://lifestyle.kompas.com/parenting
# https://lifestyle.kompas.com/beauty
# https://genbest.kompas.com
# https://buku.kompas.com
# https://www.kompas.com/tren?source=navbar
# https://lestari.kompas.com?source=navbar
# https://health.kompas.com?source=navbar
# https://money.kompas.com/?source=navbar
# https://money.kompas.com/ekbis
# https://money.kompas.com/keuangan
# https://money.kompas.com/syariah
# https://money.kompas.com/industri
# https://money.kompas.com/energi
# https://money.kompas.com/karier
# https://money.kompas.com/cuan
# https://money.kompas.com/belanja
# https://kilasbadan.kompas.com/
# https://kilastransportasi.kompas.com/
# https://kilasfintech.kompas.com/
# https://kilasperbankan.kompas.com/
# https://kolom.kompas.com/Tanya.Pajak
# https://money.kompas.com/search
# https://kilasinvestasi.kompas.com/
# https://properti.kompas.com/?source=navbar
# https://www.kompas.com/properti
# https://properti.kompas.com/hunian
# https://properti.kompas.com/arsitektur
# https://properti.kompas.com/beranda
# https://properti.kompas.com/konsultasi
# https://properti.kompas.com/figur
# https://properti.kompas.com/tips
# https://properti.kompas.com/galeri-360
# https://properti.kompas.com/search
# https://sorot.kompas.com
# https://www.kompas.com/food?source=navbar
# https://www.kompas.com/food/resep
# https://www.kompas.com/food/tips-kuliner
# https://www.kompas.com/food/food-news
# https://www.kompas.com/food/food-story
# https://www.kompas.com/food/tempat-makan
# https://www.kompas.com/food/gallery
# https://kilasfood.kompas.com
# https://www.kompas.com/food/panduan-kuliner-yogyakarta
# https://umkm.kompas.com/?source=navbar
# https://umkm.kompas.com
# https://umkm.kompas.com/training
# https://umkm.kompas.com/jagoan-lokal
# https://umkm.kompas.com/program
# https://kilasumkm.kompas.com
# https://sorotumkm.kompas.com
# https://edukasi.kompas.com/?source=navbar
# https://edukasi.kompas.com/sekolah
# https://www.kompas.com/edu
# https://edukasi.kompas.com/perguruan-tinggi
# https://edukasi.kompas.com/pendidikan-khusus
# https://edukasi.kompas.com/beasiswa
# https://edukasi.kompas.com/literasi
# https://www.kompas.com/skola
# https://kilaspendidikan.kompas.com
# https://travel.kompas.com/?source=navbar
# https://travel.kompas.com/travel-news
# https://travel.kompas.com/travel-ideas
# https://travel.kompas.com/hotel-story
# https://travel.kompas.com/travelpedia
# https://travel.kompas.com/galeri
# https://ohayojepang.kompas.com
# https://travel.kompas.com/search
# #
# https://video.kompas.com?source=navbar
# https://www.kompas.com/hype?source=navbar
# https://www.kompas.com/parapuan?source=navbar
# https://kolom.kompas.com/?source=navbar
# https://www.kompas.com/sains?source=navbar
# https://jeo.kompas.com/?source=navbar
# https://foto.kompas.com/photo?source=navbar
# https://vik.kompas.com/?source=navbar
# https://www.kompas.com/homey?source=navbar
# https://lestari.kompas.com/pemerintah
# https://lestari.kompas.com/swasta
# https://lestari.kompas.com/lsm-figur
# https://lestari.kompas.com/bumn
# https://lestari.kompas.com/category/kesehatan
# https://lestari.kompas.com/tujuan/kehidupan-sehat-dan-sejahtera
# https://lestari.kompas.com/tujuan/air-bersih-dan-sanitasi-layak
# https://lestari.kompas.com/category/pendidikan
# https://lestari.kompas.com/tujuan/pendidikan-berkualitas
# https://lestari.kompas.com/category/lingkungan
# https://lestari.kompas.com/tujuan/energi-bersih-dan-terjangkau
# https://lestari.kompas.com/tujuan/penanganan-perubahan-iklim
# https://lestari.kompas.com/tujuan/ekosistem-lautan
# https://lestari.kompas.com/tujuan/ekosistem-daratan
# https://lestari.kompas.com/category/ekonomi-dan-umkm
# https://lestari.kompas.com/tujuan/tanpa-kemiskinan
# https://lestari.kompas.com/tujuan/tanpa-kelaparan
# https://lestari.kompas.com/tujuan/kesetaraan-gender
# https://lestari.kompas.com/tujuan/pekerjaan-layak-dan-pertumbuhan-ekonomi
# https://lestari.kompas.com/tujuan/industri-inovasi-dan-infrastruktur
# https://lestari.kompas.com/tujuan/berkurangnya-kesenjangan
# https://lestari.kompas.com/tujuan/kota-dan-pemukiman-yang-berkelanjutan
# https://lestari.kompas.com/tujuan/konsumsi-dan-produksi-yang-bertanggungjawab
# https://lestari.kompas.com/program/cantikpreneurship
# https://lestari.kompas.com/program/jernihkan-bumi
# https://bola.kompas.com/klasemen/liga-inggris
# https://bola.kompas.com/klasemen/liga-inggris
# https://bola.kompas.com/klasemen/liga-italia
# https://bola.kompas.com/klasemen/liga-italia
# https://bola.kompas.com/klasemen/bundesliga
# https://bola.kompas.com/klasemen/bundesliga
# https://bola.kompas.com/klasemen/liga-spanyol
# https://bola.kompas.com/klasemen/liga-spanyol
# https://bola.kompas.com/klasemen/liga-prancis
# https://bola.kompas.com/klasemen/liga-prancis
# https://bola.kompas.com/klasemen/liga-indonesia
# https://bola.kompas.com/klasemen/liga-indonesia
# https://bola.kompas.com/klasemen/olimpiade
# https://bola.kompas.com/klasemen/olimpiade
# https://traid.jixie.io/sync/ck?desturl=https%3A%2F%2Fplus.kompas.com%2F%3Fsource%3DKompas.com%26medium%3Dbelowads%26campaign%3DBacaBeritaTanpaIklan&cid=3085&cpid=804
# #
# https://www.kompas.com
# http://www.facebook.com/kompascom
# http://www.twitter.com/kompascom
# https://t.me/kompascomupdate
# http://instagram.com/kompascom
# https://www.youtube.com/c/mykompascom
# https://kmp.im/AGFeTy
# https://line.me/ti/p/@kompas.com
# https://www.tiktok.com/@kompascom?lang=en
# https://apps.apple.com/id/app/kompas-com-berita-terpercaya/id535483055
# https://play.google.com/store/apps/details?id=com.ertanto.kompas.official&hl=en&gl=US
# #
# https://money.kompas.com/read/2019/08/01/124215826/kompascom-kembali-jadi-pemenang-kategori-media-online-tepercaya
# https://ifcncodeofprinciples.poynter.org/profile/pt-kompas-cyber-media
# javascript:void(0)
# https://news.kompas.com?source=kompascom&medium=footer
# https://nasional.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/global?source=kompascom&medium=footer
# https://megapolitan.kompas.com?source=kompascom&medium=footer
# https://regional.kompas.com?source=kompascom&medium=footer
# https://pemilu.kompas.com/?source=kompascom&medium=footer
# https://ikn.kompas.com/?source=kompascom&medium=footer
# https://bola.kompas.com?source=kompascom&medium=footer
# https://tekno.kompas.com?source=kompascom&medium=footer
# https://otomotif.kompas.com?source=kompascom&medium=footer
# https://entertainment.kompas.com?source=kompascom&medium=footer
# https://sains.kompas.com?source=kompascom&medium=footer
# https://health.kompas.com?source=kompascom&medium=footer
# https://money.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/tren?source=kompascom&medium=footer
# https://properti.kompas.com?source=kompascom&medium=footer
# https://lifestyle.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/hype?source=kompascom&medium=footer
# https://travel.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/homey?source=kompascom&medium=footer
# https://www.kompas.com/food?source=kompascom&medium=footer
# https://umkm.kompas.com?source=kompascom&medium=footer
# https://edukasi.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/parapuan?source=kompascom&medium=footer
# https://foto.kompas.com?source=kompascom&medium=footer
# https://video.kompas.com?source=kompascom&medium=footer
# https://kolom.kompas.com?source=kompascom&medium=footer
# https://vik.kompas.com?source=kompascom&medium=footer
# https://jeo.kompas.com?source=kompascom&medium=footer
# https://lestari.kompas.com?source=kompascom&medium=footer
# https://ohayojepang.kompas.com?source=kompascom&medium=footer
# https://pesonaindonesia.kompas.com?source=kompascom&medium=footer
# https://play.kompas.com?source=kompascom&medium=footer
# https://indeks.kompas.com/terpopuler?source=kompascom&medium=footer
# https://indeks.kompas.com?source=kompascom&medium=footer
# https://www.kompas.com/topik-pilihan?source=kompascom&medium=footer
# https://indeks.kompas.com/headline?source=kompascom&medium=footer
# https://kompas.com?source=kompascom&medium=footer
# https://kompas.id?source=kompascom&medium=footer
# https://www.kompas.tv?source=kompascom&medium=footer
# https://www.kompasiana.com?source=kompascom&medium=footer
# https://www.kgmedia.id?source=kompascom&medium=footer
# https://www.kgnow.com?source=kompascom&medium=footer
# https://pasangiklan.com?source=kompascom&medium=footer
# https://www.kontan.co.id?source=kompascom&medium=footer
# https://www.sonora.id?source=kompascom&medium=footer
# https://www.grid.id?source=kompascom&medium=footer
# https://www.gridoto.com?source=kompascom&medium=footer
# https://www.bolasport.com?source=kompascom&medium=footer
# https://parapuan.co/?source=kompascom&medium=footer
# https://www.tribunnews.com?source=kompascom&medium=footer
# https://www.gramedia.com?source=kompascom&medium=footer
# https://ebooks.gramedia.com?source=kompascom&medium=footer
# https://kabarpalmerah.kompas.com/
# https://inside.kompas.com/about-us
# http://www.meetkcm.com/
# https://inside.kompas.com/term-of-use
# https://www.kgmedia.id/legal-privacy-id
# https://inside.kompas.com/pedoman
# https://jobs.kompas.com
# https://inside.kompas.com/about-us#meet
# https://account.kompas.com/login/a29tcGFz/aHR0cHM6Ly9wbHVzLmtvbXBhcy5jb20vc3Vic2NyaXB0aW9uL29mZmVyaW5n
# https://account.kompas.com/register/a29tcGFz/aHR0cHM6Ly9wbHVzLmtvbXBhcy5jb20vc3Vic2NyaXB0aW9uL29mZmVyaW5n
# https://account.kompas.com/login/a29tcGFz/aHR0cHM6Ly9wbHVzLmtvbXBhcy5jb20vc3Vic2NyaXB0aW9uL29mZmVyaW5n
# https://www.kgmedia.id/legal-privacy-id

# %% [markdown]
# 7. **pandas**
#
# pandas adalah pustaka untuk analisis dan manipulasi data dalam Python. Dalam konteks web scraping, pandas biasanya digunakan untuk menyimpan dan mengelola data yang diambil dari web ke dalam struktur tabel, seperti DataFrame.

# %%
import pandas as pd

# Menyimpan data ke dalam dataframe
data = {'Link_Text': [], 'Link_URL': []}

for link in links:
    text = link.text
    url = link.get('href')
    data['Link_Text'].append(text)
    data['Link_URL'].append(url)

# Membuat dataframe
df = pd.DataFrame(data)

# Menampilkan data
df.head()
# Out:
#                                    Link_Text  \
# 0                                 \n\n\n\n\n
# 1                               \n\nKoin\n\n
# 2                                     \n\n\n
# 3                                      Login
# 4  \n Voucher\n\n\nAda voucher buat kamu\n\n
#
#                                             Link_URL
# 0                             https://www.kompas.com
# 1                    https://play.kompas.com/loyalty
# 2                                 javascript:void(0)
# 3  https://account.kompas.com/login/a29tcGFz/aHR0...
# 4  https://activity.kompas.com/voucher?source=navbar
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('Link_Text').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('Link_URL').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Link_URL'].value_counts()
#     for x_label, grp in _df_8.groupby('Link_Text')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Link_Text')
# _ = plt.ylabel('Link_URL')

# %% [markdown]
# Setelah semua data crawling sudah jadi kita bisa menyimpan dataframe menjadi file CSV

# %%
# Menyimpan dataframe ke file CSV
df.to_csv('hasil_crawling_Bola.csv', index=False)
print("Data disimpan ke file hasil_crawling berita.csv")
# Out:
# Data disimpan ke file hasil_crawling berita.csv

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url, headers=headers)
